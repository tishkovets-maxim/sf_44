# %%
# import pandas as pd
# import pathlib as pth
# from datetime import datetime

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# import seaborn as sns
# import seaborn.objects as so

# Осваиваем тут:
# https://devpractice.ru/matplotlib-lesson-2-work-with-pyplot/

# %%
# Изучение
plt.__class__   # module    # это просто модуль
a = plt.plot()
a.__class__ # list          # а это уже интересно
a.__len__() # 0             # 
# справка:  Returns: list of Line2D
# т.е. plt.plot() возвращает список объектов "линия". У меня тут запущено без параметров, стлало быть объектов "линия" нет
# Out:
# 0

# %%
plt.plot([1, 7, 3, 5, 11, 1])
# передаем один список. Воспроизводит график, где y - этот список, x - его индексы

# %%
plt.plot([1, 5, 10, 15, 20], [1, 7, 3, 5, 11])
# два списка - первый x второй y
